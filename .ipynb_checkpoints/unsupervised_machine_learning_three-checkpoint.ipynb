# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('food_ratings_-_DS003.csv', index_col='student')
df = df.iloc[:12,:]
df
# Out:
#               broccoli  brussels_sprouts hamburger oysters (raw)  \
# student
# Akbar              7.0               0.0         5             2
# Andreas            7.0               7.0         7             2
# Dónal              8.0               6.0         8             5
# Hana               5.0               8.0         8             8
# Konstantinos       5.0               7.0         1             0
# Kristina           9.0               8.0         5             0
# Sabrina            6.0               8.0        10             0
# Sandrine          10.0               2.0         8             0
# Sevgi              6.0               2.0         9             0
# Rias               8.0               6.0         8             5
# Ben                8.0               8.0         5             4
# Joan               6.0               0.0         8             0
#
#                onion (raw)  peas  olives  blue_cheese  whisky   age  \
# student
# Akbar                  3.0   4.0     8.0          8.0     7.0  32.0
# Andreas                6.0   2.0     3.0          5.0     6.0  34.0
# Dónal                  1.0   5.0     8.0         10.0    10.0  35.0
# Hana                   5.0   7.0     9.0          8.0     7.0  31.0
# Konstantinos           7.0   8.0    10.0          2.0     7.0  28.0
# Kristina               7.0   7.0     9.0          4.0     7.0  36.0
# Sabrina                8.0   8.0    10.0          0.0     2.0  30.0
# Sandrine               5.0   8.0    10.0         10.0     0.0  41.0
# Sevgi                  5.0   7.0    10.0          0.0     0.0  38.0
# Rias                   0.0   6.0     8.0          8.0    10.0  33.0
# Ben                    5.0   9.0    10.0          9.0    10.0  35.0
# Joan                   7.0   2.0     8.0          9.0     6.0  88.0
#
#              favorite_color
# student
# Akbar                  Blue
# Andreas                Blue
# Dónal                 Brown
# Hana                  Green
# Konstantinos           Blue
# Kristina                red
# Sabrina               black
# Sandrine               Blue
# Sevgi                 Green
# Rias                   blue
# Ben                  Yellow
# Joan                  green

# %%
df.drop(['age', 'favorite_color'], axis=1, inplace=True)

# %%
df
# Out:
#               broccoli  brussels_sprouts hamburger oysters (raw)  \
# student
# Akbar              7.0               0.0         5             2
# Andreas            7.0               7.0         7             2
# Dónal              8.0               6.0         8             5
# Hana               5.0               8.0         8             8
# Konstantinos       5.0               7.0         1             0
# Kristina           9.0               8.0         5             0
# Sabrina            6.0               8.0        10             0
# Sandrine          10.0               2.0         8             0
# Sevgi              6.0               2.0         9             0
# Rias               8.0               6.0         8             5
# Ben                8.0               8.0         5             4
# Joan               6.0               0.0         8             0
#
#                onion (raw)  peas  olives  blue_cheese  whisky
# student
# Akbar                  3.0   4.0     8.0          8.0     7.0
# Andreas                6.0   2.0     3.0          5.0     6.0
# Dónal                  1.0   5.0     8.0         10.0    10.0
# Hana                   5.0   7.0     9.0          8.0     7.0
# Konstantinos           7.0   8.0    10.0          2.0     7.0
# Kristina               7.0   7.0     9.0          4.0     7.0
# Sabrina                8.0   8.0    10.0          0.0     2.0
# Sandrine               5.0   8.0    10.0         10.0     0.0
# Sevgi                  5.0   7.0    10.0          0.0     0.0
# Rias                   0.0   6.0     8.0          8.0    10.0
# Ben                    5.0   9.0    10.0          9.0    10.0
# Joan                   7.0   2.0     8.0          9.0     6.0

# %%
df.dtypes
# Out:
# broccoli            float64
# brussels_sprouts    float64
# hamburger            object
# oysters (raw)        object
#  onion (raw)        float64
# peas                float64
# olives              float64
# blue_cheese         float64
# whisky              float64
# dtype: object

# %%
df['hamburger'] = pd.to_numeric(df['hamburger'])

# %%
df['oysters (raw)'] = pd.to_numeric(df['oysters (raw)'])

# %%
sample = df.iloc[0:2,0:2]
sample
# Out:
#          broccoli  brussels_sprouts
# student
# Akbar         7.0               0.0
# Andreas       7.0               7.0

# %%
# plot the manhattan distance between two points
# plt.scatter(x, y, s = size(of dots on the chart))
plt.scatter(sample['broccoli'], sample['brussels_sprouts'], s=200)

# labelling the chart
# plt.xlim(-1, 11)
# plt.ylim(-1, 11)
plt.title('Manhattan distance from broccoli rating to brussel sprouts rating')
plt.xlabel('Broccoli rating')
plt.ylabel('Brussels sprouts rating')
plt.show()

# %%
sample = df.iloc[0:2,0:3]
sample
# Out:
#          broccoli  brussels_sprouts  hamburger
# student
# Akbar         7.0               0.0          5
# Andreas       7.0               7.0          7

# %%
# distance user 1 and user 2 for broccoli
md_m1_users1to2 = abs(sample.iloc[0,0] - sample.iloc[1,0])
md_m1_users1to2
# Out:
# 0.0

# %%
# distance user 1 and user 2 for brussel_sprouts
md_m2_users1to2 = abs(sample.iloc[0,1] - sample.iloc[1,1])
md_m2_users1to2
# Out:
# 7.0

# %%
# distance user 1 and user 2 for hamburguer
md_m3_users1to2 = abs(sample.iloc[0,2] - sample.iloc[1,2])
md_m3_users1to2
# Out:
# 2

# %%
# and now to calculate the distance between both users, it will be
md_users1to2 = md_m1_users1to2 + md_m2_users1to2 + md_m3_users1to2
md_users1to2
# Out:
# 9.0

# %%
# how can we visualize that?
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
plt.title('Andreas and Akbar rating positions')
ax.scatter(xs=sample['broccoli'], ys=sample['brussels_sprouts'], zs=sample['hamburger'])
plt.show()

# %%
# 3d visualisation of all participant for Broccoli, Brussel Sprouts, and Hamburgers
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
plt.title('Broccoli, brussel_sprouts and hamburger ratings')
ax.scatter(xs=df['broccoli'], ys=df['brussels_sprouts'], zs=df['hamburger'])
plt.show()

# %%
# for index, row in food.iterrows():
#     for i in range((index+1),12):

#         # distance user 1 and user 2 for broccoli
#         distance1 = abs(row.iloc[1] - food.iloc[i,1])
#         distance2 = abs(row.iloc[2] - food.iloc[i,2])
#         distance3 = abs(row.iloc[3] - food.iloc[i,3])
#         total = distance1 + distance2 + distance3
#         print(f"Distance for {row.iloc[0]} and {food.iloc[i].student} is {total}")

# %%
results = {
    'comparison': [],
    'Manhattan_distance': []
}
for i in range(len(sample.index)):
    for j in range(i, len(sample.index)):
        if i != j:
            results['comparison'].append(sample.iloc[i].name+' vs '+sample.iloc[j].name)
            results['Manhattan_distance'].append(sum(abs(sample.iloc[i] - sample.iloc[j])))
            
results = pd.DataFrame(results).set_index('comparison')
results
sample = df.iloc[0:,0:3]
results = {
    'comparison': [],
    'Manhattan_distance': []
}
for i in range(len(sample.index)):
    for j in range(i, len(sample.index)):
        if i != j:
            results['comparison'].append(sample.iloc[i].name+' vs '+sample.iloc[j].name)
            results['Manhattan_distance'].append(sum(abs(sample.iloc[i] - sample.iloc[j])))
            
results = pd.DataFrame(results).set_index('comparison')
results
# Out:
#                        Manhattan_distance
# comparison
# Akbar vs Andreas                      9.0
# Akbar vs Dónal                       10.0
# Akbar vs Hana                        13.0
# Akbar vs Konstantinos                13.0
# Akbar vs Kristina                    10.0
# ...                                   ...
# Sevgi vs Ben                         12.0
# Sevgi vs Joan                         3.0
# Rias vs Ben                           5.0
# Rias vs Joan                          8.0
# Ben vs Joan                          13.0
#
# [66 rows x 1 columns]

# %%
# create a for loop to automate the process for all the students (only the first three columns)
all_distances = []

for student in df.index: 
    
    # get the rating for the first three columns 
    broccoli = df.loc[student][0]
    brussel_sprouts = df.loc[student][1]
    hamburguer = df.loc[student][2]

    print(f'{student} ratings for broccoli: {broccoli}, brussel_sprouts: {brussel_sprouts} and hamburger {hamburguer}')
    
    student_distance = []

    # now compare its ratings with everyone else: 
    for student_to_compare in df.index:
        
        # get the ratings for the other students to compare
        broccoli_to_compare = df.loc[student_to_compare][0]
        brussel_sprouts_to_compare = df.loc[student_to_compare][1]
        hamburguer_to_compare = df.loc[student_to_compare][2]
        
        # look for the distances between both students
        broccoli_distance = abs(broccoli - broccoli_to_compare)
        brussel_sprouts_distance = abs(brussel_sprouts - brussel_sprouts_to_compare)
        hamburguer_distance = abs(hamburguer - hamburguer_to_compare)
        
        # summarise distance between both students
        distance = broccoli_distance + brussel_sprouts_distance + hamburguer_distance
        
        print(f'The distance between {student} and {student_to_compare} is {distance}')
        
        # store the distance
        student_distance.append(distance)
        
    # the list of distances of an specific student
    print(f'The distances from {student} are {student_distance}')
    
    # store the student distances in all the students distances
    all_distances.append(student_distance)
# Out:
# Akbar ratings for broccoli: 7.0, brussel_sprouts: 0.0 and hamburger 5.0
# The distance between Akbar and Akbar is 0.0
# The distance between Akbar and Andreas is 9.0
# The distance between Akbar and Dónal is 10.0
# The distance between Akbar and Hana is 13.0
# The distance between Akbar and Konstantinos is 13.0
# The distance between Akbar and Kristina is 10.0
# The distance between Akbar and Sabrina is 14.0
# The distance between Akbar and Sandrine is 8.0
# The distance between Akbar and Sevgi is 7.0
# The distance between Akbar and Rias is 10.0
# The distance between Akbar and Ben is 9.0
# The distance between Akbar and Joan is 4.0
# The distances from Akbar are [0.0, 9.0, 10.0, 13.0, 13.0, 10.0, 14.0, 8.0, 7.0, 10.0, 9.0, 4.0]
# Andreas ratings for broccoli: 7.0, brussel_sprouts: 7.0 and hamburger 7.0
# The distance between Andreas and Akbar is 9.0
# The distance between Andreas and Andreas is 0.0
# The distance between Andreas and Dónal is 3.0
# The distance between Andreas and Hana is 4.0
# The distance between Andreas and Konstantinos is 8.0
# The distance between Andreas and Kristina is 5.0
# The distance between Andreas and Sabrina is 5.0
# The distance between Andreas and Sandrine is 9.0
# The distance between Andreas and Sevgi is 8.0
# The distance between Andreas and Rias is 3.0
# The distance between Andreas and Ben is 4.0
# The distance between Andreas and Joan is 9.0
# The distances from Andreas are [9.0, 0.0, 3.0, 4.0, 8.0, 5.0, 5.0, 9.0, 8.0, 3.0, 4.0, 9.0]
# Dónal ratings for broccoli: 8.0, brussel_sprouts: 6.0 and hamburger 8.0
# The distance between Dónal and Akbar is 10.0
# The distance between Dónal and Andreas is 3.0
# The distance between Dónal and Dónal is 0.0
# The distance between Dónal and Hana is 5.0
# The distance between Dónal and Konstantinos is 11.0
# The distance between Dónal and Kristina is 6.0
# The distance between Dónal and Sabrina is 6.0
# The distance between Dónal and Sandrine is 6.0
# The distance between Dónal and Sevgi is 7.0
# The distance between Dónal and Rias is 0.0
# The distance between Dónal and Ben is 5.0
# The distance between Dónal and Joan is 8.0
# The distances from Dónal are [10.0, 3.0, 0.0, 5.0, 11.0, 6.0, 6.0, 6.0, 7.0, 0.0, 5.0, 8.0]
# Hana ratings for broccoli: 5.0, brussel_sprouts: 8.0 and hamburger 8.0
# The distance between Hana and Akbar is 13.0
# The distance between Hana and Andreas is 4.0
# The distance between Hana and Dónal is 5.0
# The distance between Hana and Hana is 0.0
# The distance between Hana and Konstantinos is 8.0
# The distance between Hana and Kristina is 7.0
# The distance between Hana and Sabrina is 3.0
# The distance between Hana and Sandrine is 11.0
# The distance between Hana and Sevgi is 8.0
# The distance between Hana and Rias is 5.0
# The distance between Hana and Ben is 6.0
# The distance between Hana and Joan is 9.0
# The distances from Hana are [13.0, 4.0, 5.0, 0.0, 8.0, 7.0, 3.0, 11.0, 8.0, 5.0, 6.0, 9.0]
# Konstantinos ratings for broccoli: 5.0, brussel_sprouts: 7.0 and hamburger 1.0
# The distance between Konstantinos and Akbar is 13.0
# The distance between Konstantinos and Andreas is 8.0
# The distance between Konstantinos and Dónal is 11.0
# The distance between Konstantinos and Hana is 8.0
# The distance between Konstantinos and Konstantinos is 0.0
# The distance between Konstantinos and Kristina is 9.0
# The distance between Konstantinos and Sabrina is 11.0
# The distance between Konstantinos and Sandrine is 17.0
# The distance between Konstantinos and Sevgi is 14.0
# The distance between Konstantinos and Rias is 11.0
# The distance between Konstantinos and Ben is 8.0
# The distance between Konstantinos and Joan is 15.0
# The distances from Konstantinos are [13.0, 8.0, 11.0, 8.0, 0.0, 9.0, 11.0, 17.0, 14.0, 11.0, 8.0, 15.0]
# Kristina ratings for broccoli: 9.0, brussel_sprouts: 8.0 and hamburger 5.0
# The distance between Kristina and Akbar is 10.0
# The distance between Kristina and Andreas is 5.0
# The distance between Kristina and Dónal is 6.0
# The distance between Kristina and Hana is 7.0
# The distance between Kristina and Konstantinos is 9.0
# The distance between Kristina and Kristina is 0.0
# The distance between Kristina and Sabrina is 8.0
# The distance between Kristina and Sandrine is 10.0
# The distance between Kristina and Sevgi is 13.0
# The distance between Kristina and Rias is 6.0
# The distance between Kristina and Ben is 1.0
# The distance between Kristina and Joan is 14.0
# The distances from Kristina are [10.0, 5.0, 6.0, 7.0, 9.0, 0.0, 8.0, 10.0, 13.0, 6.0, 1.0, 14.0]
# Sabrina ratings for broccoli: 6.0, brussel_sprouts: 8.0 and hamburger 10.0
# The distance between Sabrina and Akbar is 14.0
# The distance between Sabrina and Andreas is 5.0
# The distance between Sabrina and Dónal is 6.0
# The distance between Sabrina and Hana is 3.0
# The distance between Sabrina and Konstantinos is 11.0
# The distance between Sabrina and Kristina is 8.0
# The distance between Sabrina and Sabrina is 0.0
# The distance between Sabrina and Sandrine is 12.0
# The distance between Sabrina and Sevgi is 7.0
# The distance between Sabrina and Rias is 6.0
# The distance between Sabrina and Ben is 7.0
# The distance between Sabrina and Joan is 10.0
# The distances from Sabrina are [14.0, 5.0, 6.0, 3.0, 11.0, 8.0, 0.0, 12.0, 7.0, 6.0, 7.0, 10.0]
# Sandrine ratings for broccoli: 10.0, brussel_sprouts: 2.0 and hamburger 8.0
# The distance between Sandrine and Akbar is 8.0
# The distance between Sandrine and Andreas is 9.0
# The distance between Sandrine and Dónal is 6.0
# The distance between Sandrine and Hana is 11.0
# The distance between Sandrine and Konstantinos is 17.0
# The distance between Sandrine and Kristina is 10.0
# The distance between Sandrine and Sabrina is 12.0
# The distance between Sandrine and Sandrine is 0.0
# The distance between Sandrine and Sevgi is 5.0
# The distance between Sandrine and Rias is 6.0
# The distance between Sandrine and Ben is 11.0
# The distance between Sandrine and Joan is 6.0
# The distances from Sandrine are [8.0, 9.0, 6.0, 11.0, 17.0, 10.0, 12.0, 0.0, 5.0, 6.0, 11.0, 6.0]
# Sevgi ratings for broccoli: 6.0, brussel_sprouts: 2.0 and hamburger 9.0
# The distance between Sevgi and Akbar is 7.0
# The distance between Sevgi and Andreas is 8.0
# The distance between Sevgi and Dónal is 7.0
# The distance between Sevgi and Hana is 8.0
# The distance between Sevgi and Konstantinos is 14.0
# The distance between Sevgi and Kristina is 13.0
# The distance between Sevgi and Sabrina is 7.0
# The distance between Sevgi and Sandrine is 5.0
# The distance between Sevgi and Sevgi is 0.0
# The distance between Sevgi and Rias is 7.0
# The distance between Sevgi and Ben is 12.0
# The distance between Sevgi and Joan is 3.0
# The distances from Sevgi are [7.0, 8.0, 7.0, 8.0, 14.0, 13.0, 7.0, 5.0, 0.0, 7.0, 12.0, 3.0]
# Rias ratings for broccoli: 8.0, brussel_sprouts: 6.0 and hamburger 8.0
# The distance between Rias and Akbar is 10.0
# The distance between Rias and Andreas is 3.0
# The distance between Rias and Dónal is 0.0
# The distance between Rias and Hana is 5.0
# The distance between Rias and Konstantinos is 11.0
# The distance between Rias and Kristina is 6.0
# The distance between Rias and Sabrina is 6.0
# The distance between Rias and Sandrine is 6.0
# The distance between Rias and Sevgi is 7.0
# The distance between Rias and Rias is 0.0
# The distance between Rias and Ben is 5.0
# The distance between Rias and Joan is 8.0
# The distances from Rias are [10.0, 3.0, 0.0, 5.0, 11.0, 6.0, 6.0, 6.0, 7.0, 0.0, 5.0, 8.0]
# Ben ratings for broccoli: 8.0, brussel_sprouts: 8.0 and hamburger 5.0
# The distance between Ben and Akbar is 9.0
# The distance between Ben and Andreas is 4.0
# The distance between Ben and Dónal is 5.0
# The distance between Ben and Hana is 6.0
# The distance between Ben and Konstantinos is 8.0
# The distance between Ben and Kristina is 1.0
# The distance between Ben and Sabrina is 7.0
# The distance between Ben and Sandrine is 11.0
# The distance between Ben and Sevgi is 12.0
# The distance between Ben and Rias is 5.0
# The distance between Ben and Ben is 0.0
# The distance between Ben and Joan is 13.0
# The distances from Ben are [9.0, 4.0, 5.0, 6.0, 8.0, 1.0, 7.0, 11.0, 12.0, 5.0, 0.0, 13.0]
# Joan ratings for broccoli: 6.0, brussel_sprouts: 0.0 and hamburger 8.0
# The distance between Joan and Akbar is 4.0
# The distance between Joan and Andreas is 9.0
# The distance between Joan and Dónal is 8.0
# The distance between Joan and Hana is 9.0
# The distance between Joan and Konstantinos is 15.0
# The distance between Joan and Kristina is 14.0
# The distance between Joan and Sabrina is 10.0
# The distance between Joan and Sandrine is 6.0
# The distance between Joan and Sevgi is 3.0
# The distance between Joan and Rias is 8.0
# The distance between Joan and Ben is 13.0
# The distance between Joan and Joan is 0.0
# The distances from Joan are [4.0, 9.0, 8.0, 9.0, 15.0, 14.0, 10.0, 6.0, 3.0, 8.0, 13.0, 0.0]

# %%
all_distances
# Out:
# [[0.0, 9.0, 10.0, 13.0, 13.0, 10.0, 14.0, 8.0, 7.0, 10.0, 9.0, 4.0],
#  [9.0, 0.0, 3.0, 4.0, 8.0, 5.0, 5.0, 9.0, 8.0, 3.0, 4.0, 9.0],
#  [10.0, 3.0, 0.0, 5.0, 11.0, 6.0, 6.0, 6.0, 7.0, 0.0, 5.0, 8.0],
#  [13.0, 4.0, 5.0, 0.0, 8.0, 7.0, 3.0, 11.0, 8.0, 5.0, 6.0, 9.0],
#  [13.0, 8.0, 11.0, 8.0, 0.0, 9.0, 11.0, 17.0, 14.0, 11.0, 8.0, 15.0],
#  [10.0, 5.0, 6.0, 7.0, 9.0, 0.0, 8.0, 10.0, 13.0, 6.0, 1.0, 14.0],
#  [14.0, 5.0, 6.0, 3.0, 11.0, 8.0, 0.0, 12.0, 7.0, 6.0, 7.0, 10.0],
#  [8.0, 9.0, 6.0, 11.0, 17.0, 10.0, 12.0, 0.0, 5.0, 6.0, 11.0, 6.0],
#  [7.0, 8.0, 7.0, 8.0, 14.0, 13.0, 7.0, 5.0, 0.0, 7.0, 12.0, 3.0],
#  [10.0, 3.0, 0.0, 5.0, 11.0, 6.0, 6.0, 6.0, 7.0, 0.0, 5.0, 8.0],
#  [9.0, 4.0, 5.0, 6.0, 8.0, 1.0, 7.0, 11.0, 12.0, 5.0, 0.0, 13.0],
#  [4.0, 9.0, 8.0, 9.0, 15.0, 14.0, 10.0, 6.0, 3.0, 8.0, 13.0, 0.0]]

# %%
# adding the column names to understand the table
print('Distances between students only looking at broccoli, brussel sprouts and hamburgers:')
# Create a dataframe from the results
student_manhattan_distance = pd.DataFrame(all_distances)
# Label the columns using the names in our original dataframe (df)
student_manhattan_distance.columns = df.index
# Label the rows using the names in our original dataframe (df)
student_manhattan_distance.index = df.index

student_manhattan_distance
# Out:
# Distances between students only looking at broccoli, brussel sprouts and hamburgers:
# student       Akbar  Andreas  Dónal  Hana  Konstantinos  Kristina  Sabrina  \
# student
# Akbar           0.0      9.0   10.0  13.0          13.0      10.0     14.0
# Andreas         9.0      0.0    3.0   4.0           8.0       5.0      5.0
# Dónal          10.0      3.0    0.0   5.0          11.0       6.0      6.0
# Hana           13.0      4.0    5.0   0.0           8.0       7.0      3.0
# Konstantinos   13.0      8.0   11.0   8.0           0.0       9.0     11.0
# Kristina       10.0      5.0    6.0   7.0           9.0       0.0      8.0
# Sabrina        14.0      5.0    6.0   3.0          11.0       8.0      0.0
# Sandrine        8.0      9.0    6.0  11.0          17.0      10.0     12.0
# Sevgi           7.0      8.0    7.0   8.0          14.0      13.0      7.0
# Rias           10.0      3.0    0.0   5.0          11.0       6.0      6.0
# Ben             9.0      4.0    5.0   6.0           8.0       1.0      7.0
# Joan            4.0      9.0    8.0   9.0          15.0      14.0     10.0
#
# student       Sandrine  Sevgi  Rias   Ben  Joan
# student
# Akbar              8.0    7.0  10.0   9.0   4.0
# Andreas            9.0    8.0   3.0   4.0   9.0
# Dónal              6.0    7.0   0.0   5.0   8.0
# Hana              11.0    8.0   5.0   6.0   9.0
# Konstantinos      17.0   14.0  11.0   8.0  15.0
# Kristina          10.0   13.0   6.0   1.0  14.0
# Sabrina           12.0    7.0   6.0   7.0  10.0
# Sandrine           0.0    5.0   6.0  11.0   6.0
# Sevgi              5.0    0.0   7.0  12.0   3.0
# Rias               6.0    7.0   0.0   5.0   8.0
# Ben               11.0   12.0   5.0   0.0  13.0
# Joan               6.0    3.0   8.0  13.0   0.0

# %%
import seaborn as sns
plt.subplots(figsize=(12,8))
sns.heatmap(student_manhattan_distance)
# Out:
# <AxesSubplot:xlabel='student', ylabel='student'>

# %%
temp_list = [1,2,3,4]

temp_list_plus_1 = []
for num in temp_list:
    temp_list_plus_1.append(num + 1)
temp_list_plus_1
# Out:
# [2, 3, 4, 5]

# %%
[num + 1 for num in temp_list]
# Out:
# [2, 3, 4, 5]

# %% [markdown]
# Euclidean distance:
#
# $$d = \sqrt {\left( {x_1 - x_2 } \right)^2 + \left( {y_1 - y_2 } \right)^2 }$$

# %%
import math

sample = df.iloc[0:,0:3]
heatmap_results = {
    'student_1': [],
    'student_2': [],
    'Euclidean_distance': []
}
results = {
    'comparison': [],
    'Euclidean_distance': []
}

for i in range(len(sample.index)):
    for j in range(len(sample.index)):
        heatmap_results['student_1'].append(sample.iloc[i].name)
        heatmap_results['student_2'].append(sample.iloc[j].name)
        heatmap_results['Euclidean_distance'].append(math.sqrt(sum((sample.iloc[i] - sample.iloc[j])**2)))
        
        if i != j:
            results['comparison'].append(sample.iloc[i].name+' vs '+sample.iloc[j].name)
            results['Euclidean_distance'].append(math.sqrt(sum((sample.iloc[i] - sample.iloc[j])**2)))
            
student_Euclidean_distance = pd.DataFrame(heatmap_results)
student_Euclidean_distance_pivot_table = pd.pivot_table(student_Euclidean_distance, 
                                                        values='Euclidean_distance', 
                                                        index='student_1',
                                                        columns='student_2')
plt.subplots(figsize=(12,8))
sns.heatmap(student_Euclidean_distance_pivot_table)

results = pd.DataFrame(results).set_index('comparison')
results
# Out:
#                        Euclidean_distance
# comparison
# Akbar vs Andreas                 7.280110
# Akbar vs Dónal                   6.782330
# Akbar vs Hana                    8.774964
# Akbar vs Konstantinos            8.306624
# Akbar vs Kristina                8.246211
# ...                                   ...
# Joan vs Sabrina                  8.246211
# Joan vs Sandrine                 4.472136
# Joan vs Sevgi                    2.236068
# Joan vs Rias                     6.324555
# Joan vs Ben                      8.774964
#
# [132 rows x 1 columns]

# %%
# can you do the same process than before for all the columns?
# create a function to do it for all the users
from math import sqrt
all_distances = []

for student in df.index: 

    ratings = [rating for rating in df.loc[student]]
    student_distances = []
    
    for student_to_compare in df.index: 
        ratings_to_compare = [rating_to_compare for rating_to_compare in df.loc[student_to_compare]]
        # euclidean distance formula
        distance = sqrt(sum([(ratings[pos] - ratings_to_compare[pos])**2 for pos in range(len(ratings))]))
        student_distances.append(distance)
    
    all_distances.append(student_distances)

st_euclidean_distances = pd.DataFrame(all_distances, columns =  df.index, index =  df.index)
plt.subplots(figsize=(12, 8))
sns.heatmap(st_euclidean_distances)
# Out:
# <AxesSubplot:xlabel='student', ylabel='student'>

# %%
import numpy as np

all_distances = []

for student in df.index: 
    
    # get the rating for the first three columns 
    broccoli = df.loc[student][0]
    brussel_sprouts = df.loc[student][1]
    hamburguer = df.loc[student][2]

    print(f'{student} ratings for broccoli: {broccoli}, brussel_sprouts: {brussel_sprouts} and hamburger {hamburguer}')
    
    student_distance = []

    # now compare its ratings with everyone else: 
    for student_to_compare in df.index:
        
        # get the ratings for the other students to compare
        broccoli_to_compare = df.loc[student_to_compare][0]
        brussel_sprouts_to_compare = df.loc[student_to_compare][1]
        hamburguer_to_compare = df.loc[student_to_compare][2]
        
        # look for the distances between both students
        b_dist = broccoli - broccoli_to_compare
        b_s_dist = brussel_sprouts - brussel_sprouts_to_compare
        h_dist = hamburguer - hamburguer_to_compare
        
        # summarise distance between both students
        sum_sq = np.sum(np.square(b_dist) + np.square(b_s_dist) + np.square(h_dist))
        distance = np.sqrt(sum_sq)
        
        print(f'The distance between {student} and {student_to_compare} is {distance}')
        
        # store the distance
        student_distance.append(distance)
        
    # the list of distances of an specific student
    print(f'The distances from {student} are {student_distance}')
    
    # store the student distances in all the students distances
    all_distances.append(student_distance)
# Out:
# Akbar ratings for broccoli: 7.0, brussel_sprouts: 0.0 and hamburger 5.0
# The distance between Akbar and Akbar is 0.0
# The distance between Akbar and Andreas is 7.280109889280518
# The distance between Akbar and Dónal is 6.782329983125268
# The distance between Akbar and Hana is 8.774964387392123
# The distance between Akbar and Konstantinos is 8.306623862918075
# The distance between Akbar and Kristina is 8.246211251235321
# The distance between Akbar and Sabrina is 9.486832980505138
# The distance between Akbar and Sandrine is 4.69041575982343
# The distance between Akbar and Sevgi is 4.58257569495584
# The distance between Akbar and Rias is 6.782329983125268
# The distance between Akbar and Ben is 8.06225774829855
# The distance between Akbar and Joan is 3.1622776601683795
# The distances from Akbar are [0.0, 7.280109889280518, 6.782329983125268, 8.774964387392123, 8.306623862918075, 8.246211251235321, 9.486832980505138, 4.69041575982343, 4.58257569495584, 6.782329983125268, 8.06225774829855, 3.1622776601683795]
# Andreas ratings for broccoli: 7.0, brussel_sprouts: 7.0 and hamburger 7.0
# The distance between Andreas and Akbar is 7.280109889280518
# The distance between Andreas and Andreas is 0.0
# The distance between Andreas and Dónal is 1.7320508075688772
# The distance between Andreas and Hana is 2.449489742783178
# The distance between Andreas and Konstantinos is 6.324555320336759
# The distance between Andreas and Kristina is 3.0
# The distance between Andreas and Sabrina is 3.3166247903554
# The distance between Andreas and Sandrine is 5.916079783099616
# The distance between Andreas and Sevgi is 5.477225575051661
# The distance between Andreas and Rias is 1.7320508075688772
# The distance between Andreas and Ben is 2.449489742783178
# The distance between Andreas and Joan is 7.14142842854285
# The distances from Andreas are [7.280109889280518, 0.0, 1.7320508075688772, 2.449489742783178, 6.324555320336759, 3.0, 3.3166247903554, 5.916079783099616, 5.477225575051661, 1.7320508075688772, 2.449489742783178, 7.14142842854285]
# Dónal ratings for broccoli: 8.0, brussel_sprouts: 6.0 and hamburger 8.0
# The distance between Dónal and Akbar is 6.782329983125268
# The distance between Dónal and Andreas is 1.7320508075688772
# The distance between Dónal and Dónal is 0.0
# The distance between Dónal and Hana is 3.605551275463989
# The distance between Dónal and Konstantinos is 7.681145747868608
# The distance between Dónal and Kristina is 3.7416573867739413
# The distance between Dónal and Sabrina is 3.4641016151377544
# The distance between Dónal and Sandrine is 4.47213595499958
# The distance between Dónal and Sevgi is 4.58257569495584
# The distance between Dónal and Rias is 0.0
# The distance between Dónal and Ben is 3.605551275463989
# The distance between Dónal and Joan is 6.324555320336759
# The distances from Dónal are [6.782329983125268, 1.7320508075688772, 0.0, 3.605551275463989, 7.681145747868608, 3.7416573867739413, 3.4641016151377544, 4.47213595499958, 4.58257569495584, 0.0, 3.605551275463989, 6.324555320336759]
# Hana ratings for broccoli: 5.0, brussel_sprouts: 8.0 and hamburger 8.0
# The distance between Hana and Akbar is 8.774964387392123
# The distance between Hana and Andreas is 2.449489742783178
# The distance between Hana and Dónal is 3.605551275463989
# The distance between Hana and Hana is 0.0
# The distance between Hana and Konstantinos is 7.0710678118654755
# The distance between Hana and Kristina is 5.0
# The distance between Hana and Sabrina is 2.23606797749979
# The distance between Hana and Sandrine is 7.810249675906654
# The distance between Hana and Sevgi is 6.164414002968976
# The distance between Hana and Rias is 3.605551275463989
# The distance between Hana and Ben is 4.242640687119285
# The distance between Hana and Joan is 8.06225774829855
# The distances from Hana are [8.774964387392123, 2.449489742783178, 3.605551275463989, 0.0, 7.0710678118654755, 5.0, 2.23606797749979, 7.810249675906654, 6.164414002968976, 3.605551275463989, 4.242640687119285, 8.06225774829855]
# Konstantinos ratings for broccoli: 5.0, brussel_sprouts: 7.0 and hamburger 1.0
# The distance between Konstantinos and Akbar is 8.306623862918075
# The distance between Konstantinos and Andreas is 6.324555320336759
# The distance between Konstantinos and Dónal is 7.681145747868608
# The distance between Konstantinos and Hana is 7.0710678118654755
# The distance between Konstantinos and Konstantinos is 0.0
# The distance between Konstantinos and Kristina is 5.744562646538029
# The distance between Konstantinos and Sabrina is 9.1104335791443
# The distance between Konstantinos and Sandrine is 9.9498743710662
# The distance between Konstantinos and Sevgi is 9.486832980505138
# The distance between Konstantinos and Rias is 7.681145747868608
# The distance between Konstantinos and Ben is 5.0990195135927845
# The distance between Konstantinos and Joan is 9.9498743710662
# The distances from Konstantinos are [8.306623862918075, 6.324555320336759, 7.681145747868608, 7.0710678118654755, 0.0, 5.744562646538029, 9.1104335791443, 9.9498743710662, 9.486832980505138, 7.681145747868608, 5.0990195135927845, 9.9498743710662]
# Kristina ratings for broccoli: 9.0, brussel_sprouts: 8.0 and hamburger 5.0
# The distance between Kristina and Akbar is 8.246211251235321
# The distance between Kristina and Andreas is 3.0
# The distance between Kristina and Dónal is 3.7416573867739413
# The distance between Kristina and Hana is 5.0
# The distance between Kristina and Konstantinos is 5.744562646538029
# The distance between Kristina and Kristina is 0.0
# The distance between Kristina and Sabrina is 5.830951894845301
# The distance between Kristina and Sandrine is 6.782329983125268
# The distance between Kristina and Sevgi is 7.810249675906654
# The distance between Kristina and Rias is 3.7416573867739413
# The distance between Kristina and Ben is 1.0
# The distance between Kristina and Joan is 9.055385138137417
# The distances from Kristina are [8.246211251235321, 3.0, 3.7416573867739413, 5.0, 5.744562646538029, 0.0, 5.830951894845301, 6.782329983125268, 7.810249675906654, 3.7416573867739413, 1.0, 9.055385138137417]
# Sabrina ratings for broccoli: 6.0, brussel_sprouts: 8.0 and hamburger 10.0
# The distance between Sabrina and Akbar is 9.486832980505138
# The distance between Sabrina and Andreas is 3.3166247903554
# The distance between Sabrina and Dónal is 3.4641016151377544
# The distance between Sabrina and Hana is 2.23606797749979
# The distance between Sabrina and Konstantinos is 9.1104335791443
# The distance between Sabrina and Kristina is 5.830951894845301
# The distance between Sabrina and Sabrina is 0.0
# The distance between Sabrina and Sandrine is 7.483314773547883
# The distance between Sabrina and Sevgi is 6.082762530298219
# The distance between Sabrina and Rias is 3.4641016151377544
# The distance between Sabrina and Ben is 5.385164807134504
# The distance between Sabrina and Joan is 8.246211251235321
# The distances from Sabrina are [9.486832980505138, 3.3166247903554, 3.4641016151377544, 2.23606797749979, 9.1104335791443, 5.830951894845301, 0.0, 7.483314773547883, 6.082762530298219, 3.4641016151377544, 5.385164807134504, 8.246211251235321]
# Sandrine ratings for broccoli: 10.0, brussel_sprouts: 2.0 and hamburger 8.0
# The distance between Sandrine and Akbar is 4.69041575982343
# The distance between Sandrine and Andreas is 5.916079783099616
# The distance between Sandrine and Dónal is 4.47213595499958
# The distance between Sandrine and Hana is 7.810249675906654
# The distance between Sandrine and Konstantinos is 9.9498743710662
# The distance between Sandrine and Kristina is 6.782329983125268
# The distance between Sandrine and Sabrina is 7.483314773547883
# The distance between Sandrine and Sandrine is 0.0
# The distance between Sandrine and Sevgi is 4.123105625617661
# The distance between Sandrine and Rias is 4.47213595499958
# The distance between Sandrine and Ben is 7.0
# The distance between Sandrine and Joan is 4.47213595499958
# The distances from Sandrine are [4.69041575982343, 5.916079783099616, 4.47213595499958, 7.810249675906654, 9.9498743710662, 6.782329983125268, 7.483314773547883, 0.0, 4.123105625617661, 4.47213595499958, 7.0, 4.47213595499958]
# Sevgi ratings for broccoli: 6.0, brussel_sprouts: 2.0 and hamburger 9.0
# The distance between Sevgi and Akbar is 4.58257569495584
# The distance between Sevgi and Andreas is 5.477225575051661
# The distance between Sevgi and Dónal is 4.58257569495584
# The distance between Sevgi and Hana is 6.164414002968976
# The distance between Sevgi and Konstantinos is 9.486832980505138
# The distance between Sevgi and Kristina is 7.810249675906654
# The distance between Sevgi and Sabrina is 6.082762530298219
# The distance between Sevgi and Sandrine is 4.123105625617661
# The distance between Sevgi and Sevgi is 0.0
# The distance between Sevgi and Rias is 4.58257569495584
# The distance between Sevgi and Ben is 7.483314773547883
# The distance between Sevgi and Joan is 2.23606797749979
# The distances from Sevgi are [4.58257569495584, 5.477225575051661, 4.58257569495584, 6.164414002968976, 9.486832980505138, 7.810249675906654, 6.082762530298219, 4.123105625617661, 0.0, 4.58257569495584, 7.483314773547883, 2.23606797749979]
# Rias ratings for broccoli: 8.0, brussel_sprouts: 6.0 and hamburger 8.0
# The distance between Rias and Akbar is 6.782329983125268
# The distance between Rias and Andreas is 1.7320508075688772
# The distance between Rias and Dónal is 0.0
# The distance between Rias and Hana is 3.605551275463989
# The distance between Rias and Konstantinos is 7.681145747868608
# The distance between Rias and Kristina is 3.7416573867739413
# The distance between Rias and Sabrina is 3.4641016151377544
# The distance between Rias and Sandrine is 4.47213595499958
# The distance between Rias and Sevgi is 4.58257569495584
# The distance between Rias and Rias is 0.0
# The distance between Rias and Ben is 3.605551275463989
# The distance between Rias and Joan is 6.324555320336759
# The distances from Rias are [6.782329983125268, 1.7320508075688772, 0.0, 3.605551275463989, 7.681145747868608, 3.7416573867739413, 3.4641016151377544, 4.47213595499958, 4.58257569495584, 0.0, 3.605551275463989, 6.324555320336759]
# Ben ratings for broccoli: 8.0, brussel_sprouts: 8.0 and hamburger 5.0
# The distance between Ben and Akbar is 8.06225774829855
# The distance between Ben and Andreas is 2.449489742783178
# The distance between Ben and Dónal is 3.605551275463989
# The distance between Ben and Hana is 4.242640687119285
# The distance between Ben and Konstantinos is 5.0990195135927845
# The distance between Ben and Kristina is 1.0
# The distance between Ben and Sabrina is 5.385164807134504
# The distance between Ben and Sandrine is 7.0
# The distance between Ben and Sevgi is 7.483314773547883
# The distance between Ben and Rias is 3.605551275463989
# The distance between Ben and Ben is 0.0
# The distance between Ben and Joan is 8.774964387392123
# The distances from Ben are [8.06225774829855, 2.449489742783178, 3.605551275463989, 4.242640687119285, 5.0990195135927845, 1.0, 5.385164807134504, 7.0, 7.483314773547883, 3.605551275463989, 0.0, 8.774964387392123]
# Joan ratings for broccoli: 6.0, brussel_sprouts: 0.0 and hamburger 8.0
# The distance between Joan and Akbar is 3.1622776601683795
# The distance between Joan and Andreas is 7.14142842854285
# The distance between Joan and Dónal is 6.324555320336759
# The distance between Joan and Hana is 8.06225774829855
# The distance between Joan and Konstantinos is 9.9498743710662
# The distance between Joan and Kristina is 9.055385138137417
# The distance between Joan and Sabrina is 8.246211251235321
# The distance between Joan and Sandrine is 4.47213595499958
# The distance between Joan and Sevgi is 2.23606797749979
# The distance between Joan and Rias is 6.324555320336759
# The distance between Joan and Ben is 8.774964387392123
# The distance between Joan and Joan is 0.0
# The distances from Joan are [3.1622776601683795, 7.14142842854285, 6.324555320336759, 8.06225774829855, 9.9498743710662, 9.055385138137417, 8.246211251235321, 4.47213595499958, 2.23606797749979, 6.324555320336759, 8.774964387392123, 0.0]

# %% [markdown]
# # Data Scaling

# %%
df = pd.read_csv('food_ratings_-_DS003.csv', index_col='student')
df = df.iloc[:12,:]
df
# Out:
#               broccoli  brussels_sprouts hamburger oysters (raw)  \
# student
# Akbar              7.0               0.0         5             2
# Andreas            7.0               7.0         7             2
# Dónal              8.0               6.0         8             5
# Hana               5.0               8.0         8             8
# Konstantinos       5.0               7.0         1             0
# Kristina           9.0               8.0         5             0
# Sabrina            6.0               8.0        10             0
# Sandrine          10.0               2.0         8             0
# Sevgi              6.0               2.0         9             0
# Rias               8.0               6.0         8             5
# Ben                8.0               8.0         5             4
# Joan               6.0               0.0         8             0
#
#                onion (raw)  peas  olives  blue_cheese  whisky   age  \
# student
# Akbar                  3.0   4.0     8.0          8.0     7.0  32.0
# Andreas                6.0   2.0     3.0          5.0     6.0  34.0
# Dónal                  1.0   5.0     8.0         10.0    10.0  35.0
# Hana                   5.0   7.0     9.0          8.0     7.0  31.0
# Konstantinos           7.0   8.0    10.0          2.0     7.0  28.0
# Kristina               7.0   7.0     9.0          4.0     7.0  36.0
# Sabrina                8.0   8.0    10.0          0.0     2.0  30.0
# Sandrine               5.0   8.0    10.0         10.0     0.0  41.0
# Sevgi                  5.0   7.0    10.0          0.0     0.0  38.0
# Rias                   0.0   6.0     8.0          8.0    10.0  33.0
# Ben                    5.0   9.0    10.0          9.0    10.0  35.0
# Joan                   7.0   2.0     8.0          9.0     6.0  88.0
#
#              favorite_color
# student
# Akbar                  Blue
# Andreas                Blue
# Dónal                 Brown
# Hana                  Green
# Konstantinos           Blue
# Kristina                red
# Sabrina               black
# Sandrine               Blue
# Sevgi                 Green
# Rias                   blue
# Ben                  Yellow
# Joan                  green

# %%
df.drop(['favorite_color'], axis=1, inplace=True)

# %%
df['oysters (raw)'] = pd.to_numeric(df['oysters (raw)'])
df['hamburger'] = pd.to_numeric(df['hamburger'])

# %%
df
# Out:
#               broccoli  brussels_sprouts  hamburger  oysters (raw)  \
# student
# Akbar              7.0               0.0          5              2
# Andreas            7.0               7.0          7              2
# Dónal              8.0               6.0          8              5
# Hana               5.0               8.0          8              8
# Konstantinos       5.0               7.0          1              0
# Kristina           9.0               8.0          5              0
# Sabrina            6.0               8.0         10              0
# Sandrine          10.0               2.0          8              0
# Sevgi              6.0               2.0          9              0
# Rias               8.0               6.0          8              5
# Ben                8.0               8.0          5              4
# Joan               6.0               0.0          8              0
#
#                onion (raw)  peas  olives  blue_cheese  whisky   age
# student
# Akbar                  3.0   4.0     8.0          8.0     7.0  32.0
# Andreas                6.0   2.0     3.0          5.0     6.0  34.0
# Dónal                  1.0   5.0     8.0         10.0    10.0  35.0
# Hana                   5.0   7.0     9.0          8.0     7.0  31.0
# Konstantinos           7.0   8.0    10.0          2.0     7.0  28.0
# Kristina               7.0   7.0     9.0          4.0     7.0  36.0
# Sabrina                8.0   8.0    10.0          0.0     2.0  30.0
# Sandrine               5.0   8.0    10.0         10.0     0.0  41.0
# Sevgi                  5.0   7.0    10.0          0.0     0.0  38.0
# Rias                   0.0   6.0     8.0          8.0    10.0  33.0
# Ben                    5.0   9.0    10.0          9.0    10.0  35.0
# Joan                   7.0   2.0     8.0          9.0     6.0  88.0

# %%
def min_max_scaling(col):
    min_col = min(col)
    max_col = max(col)
    norm_val = []
    for val in col:
        norm_val.append((val - min_col) / (max_col - min_col))
    return norm_val

# %%
pd.DataFrame({
    'original': df.iloc[:,0],
    'min_max_scaling': min_max_scaling(df.iloc[:,0])
})
# Out:
#               original  min_max_scaling
# student
# Akbar              7.0              0.4
# Andreas            7.0              0.4
# Dónal              8.0              0.6
# Hana               5.0              0.0
# Konstantinos       5.0              0.0
# Kristina           9.0              0.8
# Sabrina            6.0              0.2
# Sandrine          10.0              1.0
# Sevgi              6.0              0.2
# Rias               8.0              0.6
# Ben                8.0              0.6
# Joan               6.0              0.2

# %%
df_norm = df.apply(min_max_scaling, axis=0).copy()
df_norm
# Out:
#               broccoli  brussels_sprouts  hamburger  oysters (raw)  \
# student
# Akbar              0.4             0.000   0.444444          0.250
# Andreas            0.4             0.875   0.666667          0.250
# Dónal              0.6             0.750   0.777778          0.625
# Hana               0.0             1.000   0.777778          1.000
# Konstantinos       0.0             0.875   0.000000          0.000
# Kristina           0.8             1.000   0.444444          0.000
# Sabrina            0.2             1.000   1.000000          0.000
# Sandrine           1.0             0.250   0.777778          0.000
# Sevgi              0.2             0.250   0.888889          0.000
# Rias               0.6             0.750   0.777778          0.625
# Ben                0.6             1.000   0.444444          0.500
# Joan               0.2             0.000   0.777778          0.000
#
#                onion (raw)      peas    olives  blue_cheese  whisky       age
# student
# Akbar                0.375  0.285714  0.714286          0.8     0.7  0.066667
# Andreas              0.750  0.000000  0.000000          0.5     0.6  0.100000
# Dónal                0.125  0.428571  0.714286          1.0     1.0  0.116667
# Hana                 0.625  0.714286  0.857143          0.8     0.7  0.050000
# Konstantinos         0.875  0.857143  1.000000          0.2     0.7  0.000000
# Kristina             0.875  0.714286  0.857143          0.4     0.7  0.133333
# Sabrina              1.000  0.857143  1.000000          0.0     0.2  0.033333
# Sandrine             0.625  0.857143  1.000000          1.0     0.0  0.216667
# Sevgi                0.625  0.714286  1.000000          0.0     0.0  0.166667
# Rias                 0.000  0.571429  0.714286          0.8     1.0  0.083333
# Ben                  0.625  1.000000  1.000000          0.9     1.0  0.116667
# Joan                 0.875  0.000000  0.714286          0.9     0.6  1.000000

# %%
df
# Out:
#               broccoli  brussels_sprouts  hamburger  oysters (raw)  \
# student
# Akbar              7.0               0.0          5              2
# Andreas            7.0               7.0          7              2
# Dónal              8.0               6.0          8              5
# Hana               5.0               8.0          8              8
# Konstantinos       5.0               7.0          1              0
# Kristina           9.0               8.0          5              0
# Sabrina            6.0               8.0         10              0
# Sandrine          10.0               2.0          8              0
# Sevgi              6.0               2.0          9              0
# Rias               8.0               6.0          8              5
# Ben                8.0               8.0          5              4
# Joan               6.0               0.0          8              0
#
#                onion (raw)  peas  olives  blue_cheese  whisky   age
# student
# Akbar                  3.0   4.0     8.0          8.0     7.0  32.0
# Andreas                6.0   2.0     3.0          5.0     6.0  34.0
# Dónal                  1.0   5.0     8.0         10.0    10.0  35.0
# Hana                   5.0   7.0     9.0          8.0     7.0  31.0
# Konstantinos           7.0   8.0    10.0          2.0     7.0  28.0
# Kristina               7.0   7.0     9.0          4.0     7.0  36.0
# Sabrina                8.0   8.0    10.0          0.0     2.0  30.0
# Sandrine               5.0   8.0    10.0         10.0     0.0  41.0
# Sevgi                  5.0   7.0    10.0          0.0     0.0  38.0
# Rias                   0.0   6.0     8.0          8.0    10.0  33.0
# Ben                    5.0   9.0    10.0          9.0    10.0  35.0
# Joan                   7.0   2.0     8.0          9.0     6.0  88.0

# %%
# create a function that given a dataset, returns its distances in a dataframe
def distance_df(data, dist_type='euclidean'):
    """
    Given a dataframe, return the distance between all the indexes. 
    We assume the indexes represents the users/students. 
    Args: 
        * dataset 
        * distance type to perform the operation (euclidean or manhattan)
    """
    from math import sqrt
    all_distances = []
    error = False
    
    for student in data.index: 

        ratings = [rating for rating in data.loc[student]]
        student_distances = []

        for student_to_compare in data.index: 
            ratings_to_compare = [rating_to_compare for rating_to_compare in data.loc[student_to_compare]]

            if dist_type == 'euclidean':
                distance = sqrt(sum([(ratings[pos] - ratings_to_compare[pos])**2 for pos in range(len(ratings))]))
            elif dist_type == 'manhattan':
                distance = sum([abs(ratings[pos] - ratings_to_compare[pos]) for pos in range(len(ratings))])
            else: 
                print('Wrong distance type. Please choose between "manhattan" or "euclidean" distance.')
                error = True
                break
                
            student_distances.append(distance)
            
        if error: break
        
        all_distances.append(student_distances)
        
    if error is False: 
        st_euclidean_distances = pd.DataFrame(all_distances)
        st_euclidean_distances.columns = df.index
        st_euclidean_distances.index = df.index
        return st_euclidean_distances

# %%
sns.heatmap(distance_df(df))
plt.title('No scaling applied')
plt.show()

# %%
sns.heatmap(distance_df(df_norm))
plt.title('Min & Max Scaled')
plt.show()

# %% [markdown]
# # Range Scaling

# %% [markdown]
# When we normalise the ratings, we are normalising the values between the minimum and maximum of each column, which should be 0 and 10.
# But, what happens when no one has given a rate of 0 or 10 to a food?
#
# With min/max scaling the minumum and maximum of a column determine the range of that column. This can sometimes lead to obscure results in data. For example, if the lowest score for broccolli was an 8 and the highest was a 9, when we min/max scale broccoli, the 8 will become a 0, and the 9 will become a 1. The 0 and 1 will lead us to believe that these scores were very different, when in reality they were quite similar. In cases where it is appropriate, we can determine the range of our scaling: we can choose 1-10, 1-100, or even 7-99 if we should wish

# %%
def range_scaling(col):
    min_col = 0
    max_col = 10
    norm_val = []
    for val in col:
        norm_val.append((val - min_col) / (max_col - min_col))
    return norm_val

# %%
pd.DataFrame({
    'original': df.iloc[:,0],
    'range_scaling': range_scaling(df.iloc[0:,0])
})
# Out:
#               original  range_scaling
# student
# Akbar              7.0            0.7
# Andreas            7.0            0.7
# Dónal              8.0            0.8
# Hana               5.0            0.5
# Konstantinos       5.0            0.5
# Kristina           9.0            0.9
# Sabrina            6.0            0.6
# Sandrine          10.0            1.0
# Sevgi              6.0            0.6
# Rias               8.0            0.8
# Ben                8.0            0.8
# Joan               6.0            0.6

# %%
df_scaled = df.drop('age', axis=1).apply(range_scaling).copy()
df_scaled['age'] = min_max_scaling(df['age'])
df_scaled
# Out:
#               broccoli  brussels_sprouts  hamburger  oysters (raw)  \
# student
# Akbar              0.7               0.0        0.5            0.2
# Andreas            0.7               0.7        0.7            0.2
# Dónal              0.8               0.6        0.8            0.5
# Hana               0.5               0.8        0.8            0.8
# Konstantinos       0.5               0.7        0.1            0.0
# Kristina           0.9               0.8        0.5            0.0
# Sabrina            0.6               0.8        1.0            0.0
# Sandrine           1.0               0.2        0.8            0.0
# Sevgi              0.6               0.2        0.9            0.0
# Rias               0.8               0.6        0.8            0.5
# Ben                0.8               0.8        0.5            0.4
# Joan               0.6               0.0        0.8            0.0
#
#                onion (raw)  peas  olives  blue_cheese  whisky       age
# student
# Akbar                  0.3   0.4     0.8          0.8     0.7  0.066667
# Andreas                0.6   0.2     0.3          0.5     0.6  0.100000
# Dónal                  0.1   0.5     0.8          1.0     1.0  0.116667
# Hana                   0.5   0.7     0.9          0.8     0.7  0.050000
# Konstantinos           0.7   0.8     1.0          0.2     0.7  0.000000
# Kristina               0.7   0.7     0.9          0.4     0.7  0.133333
# Sabrina                0.8   0.8     1.0          0.0     0.2  0.033333
# Sandrine               0.5   0.8     1.0          1.0     0.0  0.216667
# Sevgi                  0.5   0.7     1.0          0.0     0.0  0.166667
# Rias                   0.0   0.6     0.8          0.8     1.0  0.083333
# Ben                    0.5   0.9     1.0          0.9     1.0  0.116667
# Joan                   0.7   0.2     0.8          0.9     0.6  1.000000

# %%
df_1 = df.copy()
df_1 = df_1/df_1.max()
df_1

df_2 = df.copy()
df_2 = (df_2-df_2.min())/(df_2.max()-df_2.min())
df_2
# Out:
#               broccoli  brussels_sprouts  hamburger  oysters (raw)  \
# student
# Akbar              0.4             0.000   0.444444          0.250
# Andreas            0.4             0.875   0.666667          0.250
# Dónal              0.6             0.750   0.777778          0.625
# Hana               0.0             1.000   0.777778          1.000
# Konstantinos       0.0             0.875   0.000000          0.000
# Kristina           0.8             1.000   0.444444          0.000
# Sabrina            0.2             1.000   1.000000          0.000
# Sandrine           1.0             0.250   0.777778          0.000
# Sevgi              0.2             0.250   0.888889          0.000
# Rias               0.6             0.750   0.777778          0.625
# Ben                0.6             1.000   0.444444          0.500
# Joan               0.2             0.000   0.777778          0.000
#
#                onion (raw)      peas    olives  blue_cheese  whisky       age
# student
# Akbar                0.375  0.285714  0.714286          0.8     0.7  0.066667
# Andreas              0.750  0.000000  0.000000          0.5     0.6  0.100000
# Dónal                0.125  0.428571  0.714286          1.0     1.0  0.116667
# Hana                 0.625  0.714286  0.857143          0.8     0.7  0.050000
# Konstantinos         0.875  0.857143  1.000000          0.2     0.7  0.000000
# Kristina             0.875  0.714286  0.857143          0.4     0.7  0.133333
# Sabrina              1.000  0.857143  1.000000          0.0     0.2  0.033333
# Sandrine             0.625  0.857143  1.000000          1.0     0.0  0.216667
# Sevgi                0.625  0.714286  1.000000          0.0     0.0  0.166667
# Rias                 0.000  0.571429  0.714286          0.8     1.0  0.083333
# Ben                  0.625  1.000000  1.000000          0.9     1.0  0.116667
# Joan                 0.875  0.000000  0.714286          0.9     0.6  1.000000

# %% [markdown]
# ### Moosic example

# %%
# importing libs
import pandas as pd
import numpy as np
from scipy.spatial.distance import cityblock
from IPython.display import JSON

import unicodedata
import re

# %%
df_audio_features = pd.read_csv('df_audio_features.csv')

# %%
df_audio_features.head(2)
# Out:
#              song_name  artist  danceability  energy  key  loudness  mode  \
# 0              My Band     D12         0.851   0.849    1    -3.383     0
# 1  The Real Slim Shady  Eminem         0.949   0.661    5    -4.244     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0828        0.4970          0.000002    0.1160    0.844  120.014
# 1       0.0572        0.0302          0.000000    0.0454    0.760  104.504
#
#    duration_ms  time_signature
# 0       298773               4
# 1       284200               4

# %%
df = pd.read_csv('df_audio_features.csv')#, index_col='song_name')

# %%
df_norm = df.copy()

# %%
df_without_index = df_norm.copy()

# %%
df_without_index.drop(["song_name","artist"],axis=1,inplace=True)

# %%
df.dtypes
# Out:
# song_name            object
# artist               object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# time_signature        int64
# dtype: object

# %%
df_norm.set_index(['song_name', 'artist'], inplace=True)

# %%
df_norm = df_norm.apply(min_max_scaling, axis=0)

# %%
df_norm
# Out:
#                                                                          danceability  \
# song_name                                          artist
# My Band                                            D12                       0.871895
# The Real Slim Shady                                Eminem                    1.000000
# Águas De Março                                     Antônio Carlos Jobim      0.598693
# The Girl From Ipanema                              Stan Getz                 0.597386
# Paint It, Black                                    The Rolling Stones        0.366013
# Sultans Of Swing                                   Dire Straits              0.717647
# Space Raiders - Charlotte de Witte Remix           Eats Everything           0.738562
# In Silence                                         Amelie Lens               0.721569
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms           0.000000
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin           0.265359
#
#                                                                            energy  \
# song_name                                          artist
# My Band                                            D12                   1.000000
# The Real Slim Shady                                Eminem                0.776369
# Águas De Março                                     Antônio Carlos Jobim  0.393341
# The Girl From Ipanema                              Stan Getz             0.156625
# Paint It, Black                                    The Rolling Stones    0.935766
# Sultans Of Swing                                   Dire Straits          0.934576
# Space Raiders - Charlotte de Witte Remix           Eats Everything       0.859636
# In Silence                                         Amelie Lens           0.995242
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms       0.000000
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin       0.043739
#
#                                                                               key  \
# song_name                                          artist
# My Band                                            D12                   0.000000
# The Real Slim Shady                                Eminem                0.571429
# Águas De Março                                     Antônio Carlos Jobim  0.285714
# The Girl From Ipanema                              Stan Getz             1.000000
# Paint It, Black                                    The Rolling Stones    0.000000
# Sultans Of Swing                                   Dire Straits          0.571429
# Space Raiders - Charlotte de Witte Remix           Eats Everything       0.428571
# In Silence                                         Amelie Lens           0.000000
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms       0.285714
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin       0.285714
#
#                                                                          loudness  \
# song_name                                          artist
# My Band                                            D12                   1.000000
# The Real Slim Shady                                Eminem                0.971414
# Águas De Março                                     Antônio Carlos Jobim  0.597610
# The Girl From Ipanema                              Stan Getz             0.554880
# Paint It, Black                                    The Rolling Stones    0.804648
# Sultans Of Swing                                   Dire Straits          0.779548
# Space Raiders - Charlotte de Witte Remix           Eats Everything       0.751594
# In Silence                                         Amelie Lens           0.713347
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms       0.000000
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin       0.292331
#
#                                                                          mode  \
# song_name                                          artist
# My Band                                            D12                    0.0
# The Real Slim Shady                                Eminem                 0.0
# Águas De Março                                     Antônio Carlos Jobim   1.0
# The Girl From Ipanema                              Stan Getz              1.0
# Paint It, Black                                    The Rolling Stones     1.0
# Sultans Of Swing                                   Dire Straits           1.0
# Space Raiders - Charlotte de Witte Remix           Eats Everything        1.0
# In Silence                                         Amelie Lens            1.0
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms        1.0
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin        1.0
#
#                                                                          speechiness  \
# song_name                                          artist
# My Band                                            D12                      0.476670
# The Real Slim Shady                                Eminem                   0.242452
# Águas De Março                                     Antônio Carlos Jobim     1.000000
# The Girl From Ipanema                              Stan Getz                0.075938
# Paint It, Black                                    The Rolling Stones       0.566331
# Sultans Of Swing                                   Dire Straits             0.000000
# Space Raiders - Charlotte de Witte Remix           Eats Everything          0.707228
# In Silence                                         Amelie Lens              0.064044
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms          0.193962
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin          0.052150
#
#                                                                          acousticness  \
# song_name                                          artist
# My Band                                            D12                       0.500436
# The Real Slim Shady                                Eminem                    0.027420
# Águas De Março                                     Antônio Carlos Jobim      0.862189
# The Girl From Ipanema                              Stan Getz                 0.875362
# Paint It, Black                                    The Rolling Stones        0.046775
# Sultans Of Swing                                   Dire Straits              0.059036
# Space Raiders - Charlotte de Witte Remix           Eats Everything           0.000000
# In Silence                                         Amelie Lens               0.002371
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms           0.998987
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin           1.000000
#
#                                                                          instrumentalness  \
# song_name                                          artist
# My Band                                            D12                           0.000002
# The Real Slim Shady                                Eminem                        0.000000
# Águas De Março                                     Antônio Carlos Jobim          0.000000
# The Girl From Ipanema                              Stan Getz                     0.001818
# Paint It, Black                                    The Rolling Stones            0.002673
# Sultans Of Swing                                   Dire Straits                  0.040197
# Space Raiders - Charlotte de Witte Remix           Eats Everything               0.949617
# In Silence                                         Amelie Lens                   0.986857
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms               0.652793
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin               1.000000
#
#                                                                          liveness  \
# song_name                                          artist
# My Band                                            D12                   0.199661
# The Real Slim Shady                                Eminem                0.000000
# Águas De Março                                     Antônio Carlos Jobim  0.168552
# The Girl From Ipanema                              Stan Getz             0.168552
# Paint It, Black                                    The Rolling Stones    1.000000
# Sultans Of Swing                                   Dire Straits          0.804864
# Space Raiders - Charlotte de Witte Remix           Eats Everything       0.185520
# In Silence                                         Amelie Lens           0.185520
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms       0.165724
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin       0.188348
#
#                                                                           valence  \
# song_name                                          artist
# My Band                                            D12                   0.900138
# The Real Slim Shady                                Eminem                0.803719
# Águas De Março                                     Antônio Carlos Jobim  0.494949
# The Girl From Ipanema                              Stan Getz             0.376722
# Paint It, Black                                    The Rolling Stones    0.633838
# Sultans Of Swing                                   Dire Straits          1.000000
# Space Raiders - Charlotte de Witte Remix           Eats Everything       0.000000
# In Silence                                         Amelie Lens           0.158632
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms       0.173554
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin       0.012856
#
#                                                                             tempo  \
# song_name                                          artist
# My Band                                            D12                   0.602076
# The Real Slim Shady                                Eminem                0.442503
# Águas De Março                                     Antônio Carlos Jobim  0.842866
# The Girl From Ipanema                              Stan Getz             0.697799
# Paint It, Black                                    The Rolling Stones    1.000000
# Sultans Of Swing                                   Dire Straits          0.891797
# Space Raiders - Charlotte de Witte Remix           Eats Everything       0.725362
# In Silence                                         Amelie Lens           0.684332
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms       0.000484
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin       0.000000
#
#                                                                          duration_ms  \
# song_name                                          artist
# My Band                                            D12                      0.574526
# The Real Slim Shady                                Eminem                   0.530220
# Águas De Março                                     Antônio Carlos Jobim     0.311930
# The Girl From Ipanema                              Stan Getz                0.632941
# Paint It, Black                                    The Rolling Stones       0.281123
# Sultans Of Swing                                   Dire Straits             0.726085
# Space Raiders - Charlotte de Witte Remix           Eats Everything          1.000000
# In Silence                                         Amelie Lens              0.863249
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms          0.000000
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin          0.482266
#
#                                                                          time_signature
# song_name                                          artist
# My Band                                            D12                              1.0
# The Real Slim Shady                                Eminem                           1.0
# Águas De Março                                     Antônio Carlos Jobim             1.0
# The Girl From Ipanema                              Stan Getz                        1.0
# Paint It, Black                                    The Rolling Stones               1.0
# Sultans Of Swing                                   Dire Straits                     1.0
# Space Raiders - Charlotte de Witte Remix           Eats Everything                  1.0
# In Silence                                         Amelie Lens                      1.0
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms                  0.0
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin                  1.0

# %% [markdown]
# ## MinMax func

# %%
def min_max_scaling(col):
    min_col = min(col)
    max_col = max(col)
    norm_val = []
    for val in col:
        norm_val.append((val - min_col) / (max_col - min_col))
    return norm_val

# %%
df_norm.dtypes
# Out:
# danceability        float64
# energy              float64
# key                 float64
# loudness            float64
# mode                float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms         float64
# time_signature      float64
# dtype: object

# %%
df_without_index = df_without_index.apply(min_max_scaling, axis=0)

# %%
plt.subplots(figsize=(12,8))
sns.heatmap(df_norm)
# ====== This line below will on;y give you results without the names 
# sns.heatmap(df_without_index)
plt.show()

# %% [markdown]
# # Manhattan Distance

# %%
# create a function that given a dataset, returns its distances in a dataframe
def manhattan_distance_df(data, dist_type='manhattan'):
    """
    Given a dataframe, return the distance between all the indexes. 
    We assume the indexes represents the users/students. 
    Args: 
        * dataset 
        * distance type to perform the operation (euclidean or manhattan)
    """
    from math import sqrt
    all_distances = []
    error = False
    
    for item in data.index: 

        ratings = [rating for rating in data.loc[item]]
        item_distances = []

        for item_to_compare in data.index: 
            ratings_to_compare = [rating_to_compare for rating_to_compare in data.loc[item_to_compare]]

            if dist_type == 'euclidean':
                distance = sqrt(sum([(ratings[pos] - ratings_to_compare[pos])**2 for pos in range(len(ratings))]))
            elif dist_type == 'manhattan':
                distance = sum([abs(ratings[pos] - ratings_to_compare[pos]) for pos in range(len(ratings))])
            else: 
                print('Wrong distance type. Please choose between "manhattan" or "euclidean" distance.')
                error = True
                break
                
            item_distances.append(distance)
            
        if error: break
        
        all_distances.append(item_distances)
        
    if error is False: 
        st_euclidean_distances = pd.DataFrame(all_distances)
        st_euclidean_distances.columns = df.index
        st_euclidean_distances.index = df.index
        return st_euclidean_distances

# %% [markdown]
# # Euclidean distance

# %%
# create a function that given a dataset, returns its distances in a dataframe
def euclidean_distance_df(data, dist_type='euclidean'):
    """
    Given a dataframe, return the distance between all the indexes. 
    We assume the indexes represents the users/students. 
    Args: 
        * dataset 
        * distance type to perform the operation (euclidean or manhattan)
    """
    from math import sqrt
    all_distances = []
    error = False
    
    for item in data.index: 

        ratings = [rating for rating in data.loc[item]]
        item_distances = []

        for item_to_compare in data.index: 
            ratings_to_compare = [rating_to_compare for rating_to_compare in data.loc[item_to_compare]]

            if dist_type == 'euclidean':
                distance = sqrt(sum([(ratings[pos] - ratings_to_compare[pos])**2 for pos in range(len(ratings))]))
            elif dist_type == 'manhattan':
                distance = sum([abs(ratings[pos] - ratings_to_compare[pos]) for pos in range(len(ratings))])
            else: 
                print('Wrong distance type. Please choose between "manhattan" or "euclidean" distance.')
                error = True
                break
                
            item_distances.append(distance)
            
        if error: break
        
        all_distances.append(item_distances)
        
    if error is False: 
        st_euclidean_distances = pd.DataFrame(all_distances)
        st_euclidean_distances.columns = df.index
        st_euclidean_distances.index = df.index
        return st_euclidean_distances

# %%
# df_norm.set_index(['song_name', 'artist'], inplace=True)

# %%
df_norm_manhattan = manhattan_distance_df(df_norm)

# %%
df_norm_euclid = euclidean_distance_df(df_norm)

# %% [markdown]
# ## PLOTS

# %% [markdown]
# ### Manhattan

# %%
df_norm_manhattan
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000000  2.158943  4.392734  5.049142  4.069427  4.116163  5.094322
# 1  2.158943  0.000000  5.132145  4.837304  4.853959  3.592995  4.891073
# 2  4.392734  5.132145  0.000000  2.518397  3.677891  4.575643  4.325075
# 3  5.049142  4.837304  2.518397  0.000000  5.322699  4.028828  4.855091
# 4  4.069427  4.853959  3.677891  5.322699  0.000000  2.679931  4.506753
# 5  4.116163  3.592995  4.575643  4.028828  2.679931  0.000000  4.002044
# 6  5.094322  4.891073  4.325075  4.855091  4.506753  4.002044  0.000000
# 7  4.465909  4.922580  4.971998  4.470023  4.224689  3.574927  1.638625
# 8  8.528299  8.474476  5.663808  5.452053  7.942043  8.546980  7.219954
# 9  7.073192  7.064619  4.588967  3.800492  6.889223  6.808250  4.855460
#
#           7         8         9
# 0  4.465909  8.528299  7.073192
# 1  4.922580  8.474476  7.064619
# 2  4.971998  5.663808  4.588967
# 3  4.470023  5.452053  3.800492
# 4  4.224689  7.942043  6.889223
# 5  3.574927  8.546980  6.808250
# 6  1.638625  7.219954  4.855460
# 7  0.000000  6.758284  4.351028
# 8  6.758284  0.000000  2.757533
# 9  4.351028  2.757533  0.000000

# %%
plt.subplots(figsize=(12,8))
sns.heatmap(df_norm_manhattan)
plt.show()

# %% [markdown]
# ### Euclidean

# %%
df_norm_euclid
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000000  0.865424  1.543712  1.890353  1.570970  1.519874  1.869464
# 1  0.865424  0.000000  1.769612  1.713638  1.813472  1.459289  1.801010
# 2  1.543712  1.769612  0.000000  1.249081  1.435993  1.703637  1.656648
# 3  1.890353  1.713638  1.249081  0.000000  1.903296  1.538547  1.794488
# 4  1.570970  1.813472  1.435993  1.903296  0.000000  1.074686  1.705039
# 5  1.519874  1.459289  1.703637  1.538547  1.074686  0.000000  1.686493
# 6  1.869464  1.801010  1.656648  1.794488  1.705039  1.686493  0.000000
# 7  1.771203  1.773372  1.871919  1.891412  1.639784  1.546424  0.815132
# 8  2.611037  2.627079  1.968514  1.892255  2.488509  2.605251  2.403171
# 9  2.335151  2.336751  1.793372  1.535254  2.324324  2.309939  1.829474
#
#           7         8         9
# 0  1.771203  2.611037  2.335151
# 1  1.773372  2.627079  2.336751
# 2  1.871919  1.968514  1.793372
# 3  1.891412  1.892255  1.535254
# 4  1.639784  2.488509  2.324324
# 5  1.546424  2.605251  2.309939
# 6  0.815132  2.403171  1.829474
# 7  0.000000  2.331705  1.732820
# 8  2.331705  0.000000  1.247945
# 9  1.732820  1.247945  0.000000

# %%
plt.subplots(figsize=(12,8))
sns.heatmap(df_norm_euclid)
plt.show()

# %% [markdown]
# # Let's do the same but drop a few more col !

# %%
df_original = pd.read_csv('df_audio_features.csv')#, index_col='song_name')

# %%
df_original.dtypes
# Out:
# song_name            object
# artist               object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# time_signature        int64
# dtype: object

# %%
df_exp = df_original.copy()

# %%
df_exp.set_index(['song_name', 'artist'], inplace=True)

# %%
df_exp
# Out:
#                                                                          danceability  \
# song_name                                          artist
# My Band                                            D12                          0.851
# The Real Slim Shady                                Eminem                       0.949
# Águas De Março                                     Antônio Carlos Jobim         0.642
# The Girl From Ipanema                              Stan Getz                    0.641
# Paint It, Black                                    The Rolling Stones           0.464
# Sultans Of Swing                                   Dire Straits                 0.733
# Space Raiders - Charlotte de Witte Remix           Eats Everything              0.749
# In Silence                                         Amelie Lens                  0.736
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms              0.184
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin              0.387
#
#                                                                           energy  \
# song_name                                          artist
# My Band                                            D12                   0.84900
# The Real Slim Shady                                Eminem                0.66100
# Águas De Março                                     Antônio Carlos Jobim  0.33900
# The Girl From Ipanema                              Stan Getz             0.14000
# Paint It, Black                                    The Rolling Stones    0.79500
# Sultans Of Swing                                   Dire Straits          0.79400
# Space Raiders - Charlotte de Witte Remix           Eats Everything       0.73100
# In Silence                                         Amelie Lens           0.84500
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms       0.00833
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin       0.04510
#
#                                                                          key  \
# song_name                                          artist
# My Band                                            D12                     1
# The Real Slim Shady                                Eminem                  5
# Águas De Março                                     Antônio Carlos Jobim    3
# The Girl From Ipanema                              Stan Getz               8
# Paint It, Black                                    The Rolling Stones      1
# Sultans Of Swing                                   Dire Straits            5
# Space Raiders - Charlotte de Witte Remix           Eats Everything         4
# In Silence                                         Amelie Lens             1
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms         3
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin         3
#
#                                                                          loudness  \
# song_name                                          artist
# My Band                                            D12                     -3.383
# The Real Slim Shady                                Eminem                  -4.244
# Águas De Março                                     Antônio Carlos Jobim   -15.503
# The Girl From Ipanema                              Stan Getz              -16.790
# Paint It, Black                                    The Rolling Stones      -9.267
# Sultans Of Swing                                   Dire Straits           -10.023
# Space Raiders - Charlotte de Witte Remix           Eats Everything        -10.865
# In Silence                                         Amelie Lens            -12.017
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms        -33.503
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin        -24.698
#
#                                                                          mode  \
# song_name                                          artist
# My Band                                            D12                      0
# The Real Slim Shady                                Eminem                   0
# Águas De Março                                     Antônio Carlos Jobim     1
# The Girl From Ipanema                              Stan Getz                1
# Paint It, Black                                    The Rolling Stones       1
# Sultans Of Swing                                   Dire Straits             1
# Space Raiders - Charlotte de Witte Remix           Eats Everything          1
# In Silence                                         Amelie Lens              1
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms          1
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin          1
#
#                                                                          speechiness  \
# song_name                                          artist
# My Band                                            D12                        0.0828
# The Real Slim Shady                                Eminem                     0.0572
# Águas De Março                                     Antônio Carlos Jobim       0.1400
# The Girl From Ipanema                              Stan Getz                  0.0390
# Paint It, Black                                    The Rolling Stones         0.0926
# Sultans Of Swing                                   Dire Straits               0.0307
# Space Raiders - Charlotte de Witte Remix           Eats Everything            0.1080
# In Silence                                         Amelie Lens                0.0377
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms            0.0519
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin            0.0364
#
#                                                                          acousticness  \
# song_name                                          artist
# My Band                                            D12                        0.49700
# The Real Slim Shady                                Eminem                     0.03020
# Águas De Março                                     Antônio Carlos Jobim       0.85400
# The Girl From Ipanema                              Stan Getz                  0.86700
# Paint It, Black                                    The Rolling Stones         0.04930
# Sultans Of Swing                                   Dire Straits               0.06140
# Space Raiders - Charlotte de Witte Remix           Eats Everything            0.00314
# In Silence                                         Amelie Lens                0.00548
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms            0.98900
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin            0.99000
#
#                                                                          instrumentalness  \
# song_name                                          artist
# My Band                                            D12                           0.000002
# The Real Slim Shady                                Eminem                        0.000000
# Águas De Março                                     Antônio Carlos Jobim          0.000000
# The Girl From Ipanema                              Stan Getz                     0.001660
# Paint It, Black                                    The Rolling Stones            0.002440
# Sultans Of Swing                                   Dire Straits                  0.036700
# Space Raiders - Charlotte de Witte Remix           Eats Everything               0.867000
# In Silence                                         Amelie Lens                   0.901000
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms               0.596000
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin               0.913000
#
#                                                                          liveness  \
# song_name                                          artist
# My Band                                            D12                     0.1160
# The Real Slim Shady                                Eminem                  0.0454
# Águas De Março                                     Antônio Carlos Jobim    0.1050
# The Girl From Ipanema                              Stan Getz               0.1050
# Paint It, Black                                    The Rolling Stones      0.3990
# Sultans Of Swing                                   Dire Straits            0.3300
# Space Raiders - Charlotte de Witte Remix           Eats Everything         0.1110
# In Silence                                         Amelie Lens             0.1110
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms         0.1040
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin         0.1120
#
#                                                                          valence  \
# song_name                                          artist
# My Band                                            D12                    0.8440
# The Real Slim Shady                                Eminem                 0.7600
# Águas De Março                                     Antônio Carlos Jobim   0.4910
# The Girl From Ipanema                              Stan Getz              0.3880
# Paint It, Black                                    The Rolling Stones     0.6120
# Sultans Of Swing                                   Dire Straits           0.9310
# Space Raiders - Charlotte de Witte Remix           Eats Everything        0.0598
# In Silence                                         Amelie Lens            0.1980
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms        0.2110
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin        0.0710
#
#                                                                            tempo  \
# song_name                                          artist
# My Band                                            D12                   120.014
# The Real Slim Shady                                Eminem                104.504
# Águas De Março                                     Antônio Carlos Jobim  143.418
# The Girl From Ipanema                              Stan Getz             129.318
# Paint It, Black                                    The Rolling Stones    158.691
# Sultans Of Swing                                   Dire Straits          148.174
# Space Raiders - Charlotte de Witte Remix           Eats Everything       131.997
# In Silence                                         Amelie Lens           128.009
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms        61.541
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin        61.494
#
#                                                                          duration_ms  \
# song_name                                          artist
# My Band                                            D12                        298773
# The Real Slim Shady                                Eminem                     284200
# Águas De Março                                     Antônio Carlos Jobim       212400
# The Girl From Ipanema                              Stan Getz                  317987
# Paint It, Black                                    The Rolling Stones         202267
# Sultans Of Swing                                   Dire Straits               348624
# Space Raiders - Charlotte de Witte Remix           Eats Everything            438720
# In Silence                                         Amelie Lens                393740
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms            109800
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin            268427
#
#                                                                          time_signature
# song_name                                          artist
# My Band                                            D12                                4
# The Real Slim Shady                                Eminem                             4
# Águas De Março                                     Antônio Carlos Jobim               4
# The Girl From Ipanema                              Stan Getz                          4
# Paint It, Black                                    The Rolling Stones                 4
# Sultans Of Swing                                   Dire Straits                       4
# Space Raiders - Charlotte de Witte Remix           Eats Everything                    4
# In Silence                                         Amelie Lens                        4
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms                    3
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin                    4

# %%
df_exp.drop(["mode","key","time_signature"], axis=1, inplace=True)

# %%
df_exp
# Out:
#                                                                          danceability  \
# song_name                                          artist
# My Band                                            D12                          0.851
# The Real Slim Shady                                Eminem                       0.949
# Águas De Março                                     Antônio Carlos Jobim         0.642
# The Girl From Ipanema                              Stan Getz                    0.641
# Paint It, Black                                    The Rolling Stones           0.464
# Sultans Of Swing                                   Dire Straits                 0.733
# Space Raiders - Charlotte de Witte Remix           Eats Everything              0.749
# In Silence                                         Amelie Lens                  0.736
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms              0.184
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin              0.387
#
#                                                                           energy  \
# song_name                                          artist
# My Band                                            D12                   0.84900
# The Real Slim Shady                                Eminem                0.66100
# Águas De Março                                     Antônio Carlos Jobim  0.33900
# The Girl From Ipanema                              Stan Getz             0.14000
# Paint It, Black                                    The Rolling Stones    0.79500
# Sultans Of Swing                                   Dire Straits          0.79400
# Space Raiders - Charlotte de Witte Remix           Eats Everything       0.73100
# In Silence                                         Amelie Lens           0.84500
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms       0.00833
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin       0.04510
#
#                                                                          loudness  \
# song_name                                          artist
# My Band                                            D12                     -3.383
# The Real Slim Shady                                Eminem                  -4.244
# Águas De Março                                     Antônio Carlos Jobim   -15.503
# The Girl From Ipanema                              Stan Getz              -16.790
# Paint It, Black                                    The Rolling Stones      -9.267
# Sultans Of Swing                                   Dire Straits           -10.023
# Space Raiders - Charlotte de Witte Remix           Eats Everything        -10.865
# In Silence                                         Amelie Lens            -12.017
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms        -33.503
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin        -24.698
#
#                                                                          speechiness  \
# song_name                                          artist
# My Band                                            D12                        0.0828
# The Real Slim Shady                                Eminem                     0.0572
# Águas De Março                                     Antônio Carlos Jobim       0.1400
# The Girl From Ipanema                              Stan Getz                  0.0390
# Paint It, Black                                    The Rolling Stones         0.0926
# Sultans Of Swing                                   Dire Straits               0.0307
# Space Raiders - Charlotte de Witte Remix           Eats Everything            0.1080
# In Silence                                         Amelie Lens                0.0377
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms            0.0519
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin            0.0364
#
#                                                                          acousticness  \
# song_name                                          artist
# My Band                                            D12                        0.49700
# The Real Slim Shady                                Eminem                     0.03020
# Águas De Março                                     Antônio Carlos Jobim       0.85400
# The Girl From Ipanema                              Stan Getz                  0.86700
# Paint It, Black                                    The Rolling Stones         0.04930
# Sultans Of Swing                                   Dire Straits               0.06140
# Space Raiders - Charlotte de Witte Remix           Eats Everything            0.00314
# In Silence                                         Amelie Lens                0.00548
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms            0.98900
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin            0.99000
#
#                                                                          instrumentalness  \
# song_name                                          artist
# My Band                                            D12                           0.000002
# The Real Slim Shady                                Eminem                        0.000000
# Águas De Março                                     Antônio Carlos Jobim          0.000000
# The Girl From Ipanema                              Stan Getz                     0.001660
# Paint It, Black                                    The Rolling Stones            0.002440
# Sultans Of Swing                                   Dire Straits                  0.036700
# Space Raiders - Charlotte de Witte Remix           Eats Everything               0.867000
# In Silence                                         Amelie Lens                   0.901000
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms               0.596000
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin               0.913000
#
#                                                                          liveness  \
# song_name                                          artist
# My Band                                            D12                     0.1160
# The Real Slim Shady                                Eminem                  0.0454
# Águas De Março                                     Antônio Carlos Jobim    0.1050
# The Girl From Ipanema                              Stan Getz               0.1050
# Paint It, Black                                    The Rolling Stones      0.3990
# Sultans Of Swing                                   Dire Straits            0.3300
# Space Raiders - Charlotte de Witte Remix           Eats Everything         0.1110
# In Silence                                         Amelie Lens             0.1110
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms         0.1040
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin         0.1120
#
#                                                                          valence  \
# song_name                                          artist
# My Band                                            D12                    0.8440
# The Real Slim Shady                                Eminem                 0.7600
# Águas De Março                                     Antônio Carlos Jobim   0.4910
# The Girl From Ipanema                              Stan Getz              0.3880
# Paint It, Black                                    The Rolling Stones     0.6120
# Sultans Of Swing                                   Dire Straits           0.9310
# Space Raiders - Charlotte de Witte Remix           Eats Everything        0.0598
# In Silence                                         Amelie Lens            0.1980
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms        0.2110
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin        0.0710
#
#                                                                            tempo  \
# song_name                                          artist
# My Band                                            D12                   120.014
# The Real Slim Shady                                Eminem                104.504
# Águas De Março                                     Antônio Carlos Jobim  143.418
# The Girl From Ipanema                              Stan Getz             129.318
# Paint It, Black                                    The Rolling Stones    158.691
# Sultans Of Swing                                   Dire Straits          148.174
# Space Raiders - Charlotte de Witte Remix           Eats Everything       131.997
# In Silence                                         Amelie Lens           128.009
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms        61.541
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin        61.494
#
#                                                                          duration_ms
# song_name                                          artist
# My Band                                            D12                        298773
# The Real Slim Shady                                Eminem                     284200
# Águas De Março                                     Antônio Carlos Jobim       212400
# The Girl From Ipanema                              Stan Getz                  317987
# Paint It, Black                                    The Rolling Stones         202267
# Sultans Of Swing                                   Dire Straits               348624
# Space Raiders - Charlotte de Witte Remix           Eats Everything            438720
# In Silence                                         Amelie Lens                393740
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms            109800
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin            268427

# %%
# df_exp_euclid

# %%
# df_exp_manhattan

# %% [markdown]
# ## PLOTS again

# %% [markdown]
# #### Normilize First

# %%
df_norm_exp = df_exp.apply(min_max_scaling, axis=0).copy()

# %%
df_norm_exp
# Out:
#                                                                          danceability  \
# song_name                                          artist
# My Band                                            D12                       0.871895
# The Real Slim Shady                                Eminem                    1.000000
# Águas De Março                                     Antônio Carlos Jobim      0.598693
# The Girl From Ipanema                              Stan Getz                 0.597386
# Paint It, Black                                    The Rolling Stones        0.366013
# Sultans Of Swing                                   Dire Straits              0.717647
# Space Raiders - Charlotte de Witte Remix           Eats Everything           0.738562
# In Silence                                         Amelie Lens               0.721569
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms           0.000000
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin           0.265359
#
#                                                                            energy  \
# song_name                                          artist
# My Band                                            D12                   1.000000
# The Real Slim Shady                                Eminem                0.776369
# Águas De Março                                     Antônio Carlos Jobim  0.393341
# The Girl From Ipanema                              Stan Getz             0.156625
# Paint It, Black                                    The Rolling Stones    0.935766
# Sultans Of Swing                                   Dire Straits          0.934576
# Space Raiders - Charlotte de Witte Remix           Eats Everything       0.859636
# In Silence                                         Amelie Lens           0.995242
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms       0.000000
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin       0.043739
#
#                                                                          loudness  \
# song_name                                          artist
# My Band                                            D12                   1.000000
# The Real Slim Shady                                Eminem                0.971414
# Águas De Março                                     Antônio Carlos Jobim  0.597610
# The Girl From Ipanema                              Stan Getz             0.554880
# Paint It, Black                                    The Rolling Stones    0.804648
# Sultans Of Swing                                   Dire Straits          0.779548
# Space Raiders - Charlotte de Witte Remix           Eats Everything       0.751594
# In Silence                                         Amelie Lens           0.713347
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms       0.000000
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin       0.292331
#
#                                                                          speechiness  \
# song_name                                          artist
# My Band                                            D12                      0.476670
# The Real Slim Shady                                Eminem                   0.242452
# Águas De Março                                     Antônio Carlos Jobim     1.000000
# The Girl From Ipanema                              Stan Getz                0.075938
# Paint It, Black                                    The Rolling Stones       0.566331
# Sultans Of Swing                                   Dire Straits             0.000000
# Space Raiders - Charlotte de Witte Remix           Eats Everything          0.707228
# In Silence                                         Amelie Lens              0.064044
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms          0.193962
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin          0.052150
#
#                                                                          acousticness  \
# song_name                                          artist
# My Band                                            D12                       0.500436
# The Real Slim Shady                                Eminem                    0.027420
# Águas De Março                                     Antônio Carlos Jobim      0.862189
# The Girl From Ipanema                              Stan Getz                 0.875362
# Paint It, Black                                    The Rolling Stones        0.046775
# Sultans Of Swing                                   Dire Straits              0.059036
# Space Raiders - Charlotte de Witte Remix           Eats Everything           0.000000
# In Silence                                         Amelie Lens               0.002371
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms           0.998987
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin           1.000000
#
#                                                                          instrumentalness  \
# song_name                                          artist
# My Band                                            D12                           0.000002
# The Real Slim Shady                                Eminem                        0.000000
# Águas De Março                                     Antônio Carlos Jobim          0.000000
# The Girl From Ipanema                              Stan Getz                     0.001818
# Paint It, Black                                    The Rolling Stones            0.002673
# Sultans Of Swing                                   Dire Straits                  0.040197
# Space Raiders - Charlotte de Witte Remix           Eats Everything               0.949617
# In Silence                                         Amelie Lens                   0.986857
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms               0.652793
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin               1.000000
#
#                                                                          liveness  \
# song_name                                          artist
# My Band                                            D12                   0.199661
# The Real Slim Shady                                Eminem                0.000000
# Águas De Março                                     Antônio Carlos Jobim  0.168552
# The Girl From Ipanema                              Stan Getz             0.168552
# Paint It, Black                                    The Rolling Stones    1.000000
# Sultans Of Swing                                   Dire Straits          0.804864
# Space Raiders - Charlotte de Witte Remix           Eats Everything       0.185520
# In Silence                                         Amelie Lens           0.185520
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms       0.165724
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin       0.188348
#
#                                                                           valence  \
# song_name                                          artist
# My Band                                            D12                   0.900138
# The Real Slim Shady                                Eminem                0.803719
# Águas De Março                                     Antônio Carlos Jobim  0.494949
# The Girl From Ipanema                              Stan Getz             0.376722
# Paint It, Black                                    The Rolling Stones    0.633838
# Sultans Of Swing                                   Dire Straits          1.000000
# Space Raiders - Charlotte de Witte Remix           Eats Everything       0.000000
# In Silence                                         Amelie Lens           0.158632
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms       0.173554
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin       0.012856
#
#                                                                             tempo  \
# song_name                                          artist
# My Band                                            D12                   0.602076
# The Real Slim Shady                                Eminem                0.442503
# Águas De Março                                     Antônio Carlos Jobim  0.842866
# The Girl From Ipanema                              Stan Getz             0.697799
# Paint It, Black                                    The Rolling Stones    1.000000
# Sultans Of Swing                                   Dire Straits          0.891797
# Space Raiders - Charlotte de Witte Remix           Eats Everything       0.725362
# In Silence                                         Amelie Lens           0.684332
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms       0.000484
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin       0.000000
#
#                                                                          duration_ms
# song_name                                          artist
# My Band                                            D12                      0.574526
# The Real Slim Shady                                Eminem                   0.530220
# Águas De Março                                     Antônio Carlos Jobim     0.311930
# The Girl From Ipanema                              Stan Getz                0.632941
# Paint It, Black                                    The Rolling Stones       0.281123
# Sultans Of Swing                                   Dire Straits             0.726085
# Space Raiders - Charlotte de Witte Remix           Eats Everything          1.000000
# In Silence                                         Amelie Lens              0.863249
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P... Johannes Brahms          0.000000
# Nocturne en mi bémol majeur opus 9 n°2: Ballade... Frédéric Chopin          0.482266

# %%
plt.subplots(figsize=(12,8))
sns.heatmap(df_norm_exp)
plt.show()

# %%
df_exp_euclid = euclidean_distance_df(df_norm_exp)
plt.subplots(figsize=(12,8))
sns.heatmap(df_exp_euclid)
plt.show()

# %% [markdown]
# ### Euclidean

# %%
df_exp_euclid
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000000  0.649944  1.140795  1.254366  1.211589  0.991710  1.520270
# 1  0.649944  0.000000  1.431745  1.323964  1.400767  1.062791  1.491050
# 2  1.140795  1.431745  0.000000  1.024695  1.407282  1.679508  1.650477
# 3  1.254366  1.323964  1.024695  0.000000  1.619425  1.477652  1.701076
# 4  1.211589  1.400767  1.407282  1.619425  0.000000  0.910175  1.650298
# 5  0.991710  1.062791  1.679508  1.477652  0.910175  0.000000  1.680432
# 6  1.520270  1.491050  1.650477  1.701076  1.650298  1.680432  0.000000
# 7  1.461903  1.348449  1.849986  1.605441  1.639784  1.436975  0.693374
# 8  2.176209  2.195430  1.695597  1.438897  2.260762  2.388661  2.180556
# 9  2.090765  2.092552  1.793372  1.358971  2.306697  2.292201  1.823888
#
#           7         8         9
# 0  1.461903  2.176209  2.090765
# 1  1.348449  2.195430  2.092552
# 2  1.849986  1.695597  1.793372
# 3  1.605441  1.438897  1.358971
# 4  1.639784  2.260762  2.306697
# 5  1.436975  2.388661  2.292201
# 6  0.693374  2.180556  1.823888
# 7  0.000000  2.086915  1.709103
# 8  2.086915  0.000000  0.746570
# 9  1.709103  0.746570  0.000000

# %%
df_exp_manhattan = manhattan_distance_df(df_norm_exp)
plt.subplots(figsize=(12,8))
sns.heatmap(df_exp_manhattan)
plt.show()

# %% [markdown]
# ### Manhattan

# %%
df_exp_manhattan
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000000  1.587515  3.107020  3.049142  3.069427  2.544735  3.665750
# 1  1.587515  0.000000  3.846431  3.408733  3.282530  2.592995  3.748216
# 2  3.107020  3.846431  0.000000  1.804111  3.392177  4.289928  4.182218
# 3  3.049142  3.408733  1.804111  0.000000  4.322699  3.600256  4.283663
# 4  3.069427  3.282530  3.392177  4.322699  0.000000  2.108503  4.078182
# 5  2.544735  2.592995  4.289928  3.600256  2.108503  0.000000  3.859187
# 6  3.665750  3.748216  4.182218  4.283663  4.078182  3.859187  0.000000
# 7  3.465909  3.351151  4.686284  3.470023  4.224689  3.003499  1.210054
# 8  6.242584  6.188762  4.663808  3.737767  6.656329  7.261265  6.077097
# 9  5.787478  5.778905  4.588967  3.086206  6.603509  6.522536  4.712603
#
#           7         8         9
# 0  3.465909  6.242584  5.787478
# 1  3.351151  6.188762  5.778905
# 2  4.686284  4.663808  4.588967
# 3  3.470023  3.737767  3.086206
# 4  4.224689  6.656329  6.603509
# 5  3.003499  7.261265  6.522536
# 6  1.210054  6.077097  4.712603
# 7  0.000000  5.472570  4.065313
# 8  5.472570  0.000000  1.757533
# 9  4.065313  1.757533  0.000000

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '0.24.1'
